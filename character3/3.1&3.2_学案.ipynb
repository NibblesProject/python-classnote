# %% [markdown]
# # 3.1 初始Python
# ## 3.1.1 什么是Python？
# （1）Python 是一种面向对象、解释型的计算机程序设计**高级语言**，其语法简洁清晰，方便对数据进行组织和处理
# （2）Python 具有丰富和强大的**库**，可以支持很多日常问题的程序实现。
# （3）Python 在大多数平台上都是一种理想的脚本语言，特别适合应用程序的快速开发。

# %% [markdown]
# ## 3.1.2 Python编程环境
# （1）编写Python程序比较方便的方式是使用集成开发环境（Integrated Development Environment，简称IDE）。
# （2）IDLE是开发Python程序的基本IDE。

# %% [markdown]
# ## 3.1.3 Python的简单程序运行

# %%
print(123)
print("123")

# %%
print(123,"123","abc")

# %%
print(1 + 2)

# %%
print("1" + "2")

# %%
a = input("请输入a的值")  # input()函数的作用：输入,返回值为字符串型
print(a)

# %%
# 变量的命名规则：包含字母、数字和下划线；不能以数字开头，字母区分大小写；不能包含空格；不能使用Python保留字，如if、else、not等
# 变量的赋值
x = 2  
x, y = 1, 2  
x, y = "tk"  
x = y = z = 100  
x += 1  
x *= 2  
x %= 3

# %%
x = 2 
print(x)

# %% [markdown]
# # 3.2 Python语言基础
# ## 3.2.1 Python基本数据结构
# ![image.png](attachment:image.png)

# %%
print(1 + "2")

# %%
a = input("请输入a的值") 
print(a + 2)

# %%
a = int(input("请输入a的值")) # int()函数的作用：将字符串和数字转换成整型
print(a + 2)

# %%
a = int(input("请输入a的值："))
b = float(input("请输入b的值：")) # float()函数的作用：将字符串和数字转换成实型
print(a * b)

# %% [markdown]
# ## 3.2.2 Python算术运算符
# ![image.png](attachment:image.png)

# %%
# 体验

# %% [markdown]
# ### Python算术运算特点：
# 1.优先级数字越小，优先级越高；
# 2.只要有实数参与的运算，结果就为实数；
# 3.*运算符不可以省略；
# 4./（实除）运算的结果一定是实数；
# 5.+运算连接的前后两个数据数据类型需要一致。

# %%
# 计算式子的结果：5 + 6**2 - 7/2 + 198%3

# %% [markdown]
# ### 练一练
# 1.下列哪个选项与其他三项的数据类型不相同
# A."false"　　　B.'name' 　　　C."'Hello'"　　　D.True
#
# 2.变量sname用来存储姓名，则其数据类型为
# A.整型 　　　B.字符串型 　　　C.实型　　　D.布尔型
#
# 3.下列选项中值最大的是
# A.3 + 2 ** 3　　　B.25 % 7 * 2　　　C.13 // 2　　　D.4 - 2 * 4
#
# 4.已知a的值为1357，下列表达式的结果为13的是
# A.a // 10　　　B.a % 100　　　C.a // 100 　　　D.a % 10
#
# 5.表达式(3 + 15 // 2) / 2的值是
# A.5.5　　　B.4.5　　　C.5　　　D.5.0
#
# 6.表达式"12" * 2 + "3"的结果
# A.27　　　B."27"	　　　C.12123　　　D."12123"

# %% [markdown]
# ## 3.2.3 Python关系运算符
# ![image.png](attachment:image.png)

# %%
# 试判断下面表达式的结果:①100>99；②"a"<"A"；③"100">"99"；④"ABC">"BAC"；⑤"ab">"abc"

# %% [markdown]
# ## 3.2.4 Python逻辑运算符
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 练一练
# 7.下列选项中值为True的是
# A.5+2==13%6 or 8!=15//2　　B.'ac' in 'abcd'　　C.23%4>=3 and "a"<"A"　　D.not 15//4<=8%5
#
# 8.已知a=3，b=4，c=7，下列表达式的值为True的是
# A.a+b>c or c-a>b　　B.a+b==c and b-c==a　　C.c%b==a and c%a==b　　D.c//a>b or b%a==c%a
#
# 9.已知变量a存储了一个整数，判断a为3的倍数或者5的倍数，写出Python表达式。
