# %%
# 类型转换函数
print(int(1.56), int(-12.8), end='    ')

a, b = 11, 3
print(float(a*b))

# %%
a, b = 3, 11
c = str(a*b) # str函数：将数字转换为字符串
print(type(c)) # type函数：返回对象类型

# %%
s1 = 'aaadde1235'
s2 =  'dsihdiaa1e23dskajk'
s1, s2 = s2, s1
print(s1[len(s1)-1])

# %%
# 写出Python表达式，实现：输入实数后,输出其绝对值

# %%
print(chr(65)) # chr函数：将ASCII码转换成字符
print(ord('a')) # ord函数：将字符转换成ASCII码

# %%
print(round(1.5415)) # round函数：round(x,n)→对参数x进行四舍五入（保留n位小数）

# %%
# 写出Python表达式，实现：输入半径r后,输出其周长的值（保留两位小数）
pi=3.1415926

# %%
print(max(112, 15, 16, 8, 52, 210, 11, 0, -6, 7))
print(min(112, 15, 16, 8, 52, 210, 11, 0, -6, 7))
print(max('112', '105', '78', '8', '25', '1000'))
print(min('112', '105', '78', '8', '25', '1000'))

# %% [markdown]
# # 3.4 Python常用内建函数及顺序结构
#
# ## 内建函数
#
# 内建函数是Python内置对象类型之一，不需要额外导入任何模块即可**直接使用**。
# ![image.png](attachment:image.png)
#
#
# ## 顺序结构
#
# 顺序结构的程序代码执行方式是按语句的排列自上而下**依次**执行。
